# %% [markdown]
# ### Mini Project:Heart Attack Logistic Regression

# %%
Data Collection
Use the Kaggle Heart Attack which contains. Download if from Kaggle
https://www.kaggle.com/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv(r"C:\Users\NSTI\Downloads\archive (9)\Medicaldataset.csv")

# %%
data
# Out:
#       Age  Gender  Heart rate  Systolic blood pressure  \
# 0      64       1          66                      160
# 1      21       1          94                       98
# 2      55       1          64                      160
# 3      64       1          70                      120
# 4      55       1          64                      112
# ...   ...     ...         ...                      ...
# 1314   44       1          94                      122
# 1315   66       1          84                      125
# 1316   45       1          85                      168
# 1317   54       1          58                      117
# 1318   51       1          94                      157
#
#       Diastolic blood pressure  Blood sugar  CK-MB  Troponin    Result
# 0                           83        160.0   1.80     0.012  negative
# 1                           46        296.0   6.75     1.060  positive
# 2                           77        270.0   1.99     0.003  negative
# ...

# %%
data.head()
# Out:
#    Age  Gender  Heart rate  Systolic blood pressure  Diastolic blood pressure  \
# 0   64       1          66                      160                        83
# 1   21       1          94                       98                        46
# 2   55       1          64                      160                        77
# 3   64       1          70                      120                        55
# 4   55       1          64                      112                        65
#
#    Blood sugar  CK-MB  Troponin    Result
# 0        160.0   1.80     0.012  negative
# 1        296.0   6.75     1.060  positive
# 2        270.0   1.99     0.003  negative
# 3        270.0  13.87     0.122  positive
# 4        300.0   1.08     0.003  negative

# %%
data.tail()
# Out:
#       Age  Gender  Heart rate  Systolic blood pressure  \
# 1314   44       1          94                      122
# 1315   66       1          84                      125
# 1316   45       1          85                      168
# 1317   54       1          58                      117
# 1318   51       1          94                      157
#
#       Diastolic blood pressure  Blood sugar  CK-MB  Troponin    Result
# 1314                        67        204.0   1.63     0.006  negative
# 1315                        55        149.0   1.33     0.172  positive
# 1316                       104         96.0   1.24     4.250  positive
# 1317                        68        443.0   5.80     0.359  positive
# 1318                        79        134.0  50.89     1.770  positive

# %%
data.describe()
# Out:
#                Age       Gender   Heart rate  Systolic blood pressure  \
# count  1319.000000  1319.000000  1319.000000              1319.000000
# mean     56.191812     0.659591    78.336619               127.170584
# std      13.647315     0.474027    51.630270                26.122720
# min      14.000000     0.000000    20.000000                42.000000
# 25%      47.000000     0.000000    64.000000               110.000000
# 50%      58.000000     1.000000    74.000000               124.000000
# 75%      65.000000     1.000000    85.000000               143.000000
# max     103.000000     1.000000  1111.000000               223.000000
#
#        Diastolic blood pressure  Blood sugar        CK-MB     Troponin
# count               1319.000000  1319.000000  1319.000000  1319.000000
# mean                  72.269143   146.634344    15.274306     0.360942
# std                   14.033924    74.923045    46.327083     1.154568
# ...

# %%
data.ndim
# Out:
# 2

# %%
data.columns
# Out:
# Index(['Age', 'Gender', 'Heart rate', 'Systolic blood pressure',
#        'Diastolic blood pressure', 'Blood sugar', 'CK-MB', 'Troponin',
#        'Result'],
#       dtype='object')

# %%
data.isnull()
# Out:
#         Age  Gender  Heart rate  Systolic blood pressure  \
# 0     False   False       False                    False
# 1     False   False       False                    False
# 2     False   False       False                    False
# 3     False   False       False                    False
# 4     False   False       False                    False
# ...     ...     ...         ...                      ...
# 1314  False   False       False                    False
# 1315  False   False       False                    False
# 1316  False   False       False                    False
# 1317  False   False       False                    False
# 1318  False   False       False                    False
#
#       Diastolic blood pressure  Blood sugar  CK-MB  Troponin  Result
# 0                        False        False  False     False   False
# 1                        False        False  False     False   False
# 2                        False        False  False     False   False
# ...

# %%
data.isnull().sum()
# Out:
# Age                         0
# Gender                      0
# Heart rate                  0
# Systolic blood pressure     0
# Diastolic blood pressure    0
# Blood sugar                 0
# CK-MB                       0
# Troponin                    0
# Result                      0
# dtype: int64

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1314    False
# 1315    False
# 1316    False
# 1317    False
# 1318    False
# Length: 1319, dtype: bool

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.drop_duplicates(inplace=True)

# %%
data
# Out:
#       Age  Gender  Heart rate  Systolic blood pressure  \
# 0      64       1          66                      160
# 1      21       1          94                       98
# 2      55       1          64                      160
# 3      64       1          70                      120
# 4      55       1          64                      112
# ...   ...     ...         ...                      ...
# 1314   44       1          94                      122
# 1315   66       1          84                      125
# 1316   45       1          85                      168
# 1317   54       1          58                      117
# 1318   51       1          94                      157
#
#       Diastolic blood pressure  Blood sugar  CK-MB  Troponin    Result
# 0                           83        160.0   1.80     0.012  negative
# 1                           46        296.0   6.75     1.060  positive
# 2                           77        270.0   1.99     0.003  negative
# ...

# %%
data = pd.get_dummies(data, drop_first=True)

# %%
data
# Out:
#       Age  Gender  Heart rate  Systolic blood pressure  \
# 0      64       1          66                      160
# 1      21       1          94                       98
# 2      55       1          64                      160
# 3      64       1          70                      120
# 4      55       1          64                      112
# ...   ...     ...         ...                      ...
# 1314   44       1          94                      122
# 1315   66       1          84                      125
# 1316   45       1          85                      168
# 1317   54       1          58                      117
# 1318   51       1          94                      157
#
#       Diastolic blood pressure  Blood sugar  CK-MB  Troponin  Result_positive
# 0                           83        160.0   1.80     0.012            False
# 1                           46        296.0   6.75     1.060             True
# ...

# %%
data.describe()
# Out:
#                Age       Gender   Heart rate  Systolic blood pressure  \
# count  1319.000000  1319.000000  1319.000000              1319.000000
# mean     56.191812     0.659591    78.336619               127.170584
# std      13.647315     0.474027    51.630270                26.122720
# min      14.000000     0.000000    20.000000                42.000000
# 25%      47.000000     0.000000    64.000000               110.000000
# 50%      58.000000     1.000000    74.000000               124.000000
# 75%      65.000000     1.000000    85.000000               143.000000
# max     103.000000     1.000000  1111.000000               223.000000
#
#        Diastolic blood pressure  Blood sugar        CK-MB     Troponin
# count               1319.000000  1319.000000  1319.000000  1319.000000
# mean                  72.269143   146.634344    15.274306     0.360942
# std                   14.033924    74.923045    46.327083     1.154568
# ...

# %%
# Mean
mean_values = data.mean(numeric_only=True)
print("Mean:", mean_values)

# Median
median_values = data.median(numeric_only=True)
print("Median:", median_values)

# Mode
mode_values = data.mode()
print("Mode:", mode_values)
# Out:
# Mean: Age                          56.191812
# Gender                        0.659591
# Heart rate                   78.336619
# Systolic blood pressure     127.170584
# Diastolic blood pressure     72.269143
# Blood sugar                 146.634344
# CK-MB                        15.274306
# Troponin                      0.360942
# Result_positive               0.614102
# dtype: float64
# Median: Age                          58.000
# Gender                        1.000
# Heart rate                   74.000
# Systolic blood pressure     124.000
# Diastolic blood pressure     72.000
# Blood sugar                 116.000
# CK-MB                         2.850
# Troponin                      0.014
# Result_positive               1.000
# dtype: float64
# Mode:    Age  Gender  Heart rate  Systolic blood pressure  Diastolic blood pressure  \
# 0   60       1          60                      150                        75
#
#    Blood sugar  CK-MB  Troponin  Result_positive
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.plot(data.index, data['Gender'], label='spam', color='r')
plt.title('Line Plot')
plt.xlabel('and')
plt.ylabel('Gender	')
plt.legend()
plt.show()
# Out:
# C:\Users\NSTI\anaconda3f\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv(r"C:\Users\NSTI\Downloads\archive (9)\Medicaldataset.csv")

print(data.columns)

plt.scatter(data['CK-MB'], data['Systolic blood pressure'], color='pink', alpha=0.8)
plt.title("Systolic blood pressure vs CK-MB")
plt.xlabel("CK-MB")
plt.ylabel("Systolic blood pressure")
plt.grid(True)
plt.show()
# Out:
# Index(['Age', 'Gender', 'Heart rate', 'Systolic blood pressure',
#        'Diastolic blood pressure', 'Blood sugar', 'CK-MB', 'Troponin',
#        'Result'],
#       dtype='object')

# %%
X = data[[Heart rate', 'Systolic blood pressure', 'Diastolic blood pressure', 'Blood sugar', 'CK-MB',	'Systolic blood press'ure', 'Age', 'Heart rate']]
y = data['Systolic blood pressure']

# %%
X
# Out:
#       Heart rate  Systolic blood pressure  Diastolic blood pressure  \
# 0             66                      160                        83
# 1             94                       98                        46
# 2             64                      160                        77
# 3             70                      120                        55
# 4             64                      112                        65
# ...          ...                      ...                       ...
# 1314          94                      122                        67
# 1315          84                      125                        55
# 1316          85                      168                       104
# 1317          58                      117                        68
# 1318          94                      157                        79
#
#       Blood sugar  CK-MB  Systolic blood pressure  Age  Heart rate
# 0           160.0   1.80                      160   64          66
# ...

# %%
y
# Out:
# 0       160
# 1        98
# 2       160
# 3       120
# 4       112
#        ...
# 1314    122
# 1315    125
# 1316    168
# 1317    117
# 1318    157
# Name: Systolic blood pressure, Length: 1319, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=101)

# %%
X_train
# Out:
#      Heart rate  Systolic blood pressure  Diastolic blood pressure  \
# 8            60                      154                        81
# 848         119                      113                        79
# 366          59                      183                        77
# 608          65                      106                        49
# 488          67                      101                        69
# ..          ...                      ...                       ...
# 575          63                      105                        64
# 973          81                      135                        81
# 75           94                       95                        65
# 599          82                      138                        82
# 863          82                      135                        80
#
#      Blood sugar  CK-MB  Systolic blood pressure  Age  Heart rate
# 8          135.0   2.35                      154   44          60
# ...

# %%
y_train
# Out:
# 8      154
# 848    113
# 366    183
# 608    106
# 488    101
#       ...
# 575    105
# 973    135
# 75      95
# 599    138
# 863    135
# Name: Systolic blood pressure, Length: 791, dtype: int64

# %%
y_test
# Out:
# 980      76
# 446     137
# 874     140
# 1279    138
# 629      91
#        ...
# 682      98
# 743     119
# 1207    108
# 464     166
# 985     116
# Name: Systolic blood pressure, Length: 528, dtype: int64

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(lm.intercept_)
# Out:
# 0.0

# %%
coeff_df = pd.DataFrame(lm.coef_,X.columns,columns=['Coefficient'])
coeff_df
# Out:
#                            Coefficient
# Heart rate                2.157560e-17
# Systolic blood pressure   5.000000e-01
# Diastolic blood pressure  5.216617e-16
# Blood sugar              -2.787357e-17
# CK-MB                    -2.560428e-16
# Systolic blood pressure   5.000000e-01
# Age                      -1.108218e-16
# Heart rate               -4.545141e-17

# %%
predictions = lm.predict(X_test)

# %%
plt.scatter(y_test,predictions)

# %%
sns.distplot((y_test-predictions),bins=50);
# Out:
# C:\Users\NSTI\AppData\Local\Temp\ipykernel_5504\1326397652.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot((y_test-predictions),bins=50);

# %%
X = data[['Heart rate', 'Systolic blood pressure', 'Diastolic blood pressure', 'Blood sugar', 'CK-MB',	'Systolic blood pressure', 'Age', 'Heart rate']]
y = data['Systolic blood pressure']

# %%
X
# Out:
#       Heart rate  Systolic blood pressure  Diastolic blood pressure  \
# 0             66                      160                        83
# 1             94                       98                        46
# 2             64                      160                        77
# 3             70                      120                        55
# 4             64                      112                        65
# ...          ...                      ...                       ...
# 1314          94                      122                        67
# 1315          84                      125                        55
# 1316          85                      168                       104
# 1317          58                      117                        68
# 1318          94                      157                        79
#
#       Blood sugar  CK-MB  Systolic blood pressure  Age  Heart rate
# 0           160.0   1.80                      160   64          66
# ...

# %%
y
# Out:
# 0       160
# 1        98
# 2       160
# 3       120
# 4       112
#        ...
# 1314    122
# 1315    125
# 1316    168
# 1317    117
# 1318    157
# Name: Systolic blood pressure, Length: 1319, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=101)

# %%
X_train
# Out:
#      Heart rate  Systolic blood pressure  Diastolic blood pressure  \
# 8            60                      154                        81
# 848         119                      113                        79
# 366          59                      183                        77
# 608          65                      106                        49
# 488          67                      101                        69
# ..          ...                      ...                       ...
# 575          63                      105                        64
# 973          81                      135                        81
# 75           94                       95                        65
# 599          82                      138                        82
# 863          82                      135                        80
#
#      Blood sugar  CK-MB  Systolic blood pressure  Age  Heart rate
# 8          135.0   2.35                      154   44          60
# ...

# %%
X_test
# Out:
#       Heart rate  Systolic blood pressure  Diastolic blood pressure  \
# 980           62                       76                        55
# 446           71                      137                        72
# 874           64                      140                        90
# 1279          73                      138                        79
# 629           91                       91                        56
# ...          ...                      ...                       ...
# 682          135                       98                        60
# 743           85                      119                        76
# 1207          82                      108                        61
# 464           69                      166                       102
# 985           89                      116                        68
#
#       Blood sugar    CK-MB  Systolic blood pressure  Age  Heart rate
# 980         113.0    1.670                       76   65          62
# ...

# %%
y_train
# Out:
# 8      154
# 848    113
# 366    183
# 608    106
# 488    101
#       ...
# 575    105
# 973    135
# 75      95
# 599    138
# 863    135
# Name: Systolic blood pressure, Length: 791, dtype: int64

# %%
y_test
# Out:
# 980      76
# 446     137
# 874     140
# 1279    138
# 629      91
#        ...
# 682      98
# 743     119
# 1207    108
# 464     166
# 985     116
# Name: Systolic blood pressure, Length: 528, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression

# %%
lm = LogisticRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# C:\Users\NSTI\anaconda3f\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
print(lm.intercept_)
# Out:
# [ 2.50102642e-03  1.77558060e-03  7.64635702e-04  4.29229132e-03
#   2.43469472e-04  1.50251256e-03  1.77494349e-03  6.48619250e-04
#   9.32347203e-04  2.83730873e-03  7.81570582e-04  3.12899310e-03
#   6.77811182e-03  1.87903370e-03  3.89981101e-03  1.61300911e-03
#   4.62365028e-03  2.88660492e-03  3.01526881e-03  6.68136354e-04
#   2.92386608e-03  5.38614905e-03  2.98956776e-03  2.08903179e-03
#   3.08142472e-03  1.87858496e-03  3.17918469e-03  9.38397593e-04
#   2.06007912e-05  5.99569132e-03  5.58298259e-03 -1.50398688e-03
#   1.29959773e-03  1.18492161e-03  1.07432116e-03 -1.14484449e-03
#   4.93581026e-03  1.70896154e-03  7.37989870e-04  4.55928545e-04
#   1.32112960e-03 -6.97748235e-04  3.81585608e-04  1.21330817e-03
#  -1.15935903e-04  5.60339372e-04  7.90658558e-05  6.47285568e-04
#  -2.61994450e-03  1.35039822e-04  9.91773468e-05  1.08373525e-04
#  -2.17553871e-04 -3.02209673e-04 -3.70377171e-04 -1.35780670e-03
# ...

# %%
predictions = lm.predict(X_test)

# %%
plt.scatter(y_test,predictions)

# %%
sns.distplot((y_test-predictions),bins=50);
# Out:
# C:\Users\NSTI\AppData\Local\Temp\ipykernel_5504\1326397652.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot((y_test-predictions),bins=50);
